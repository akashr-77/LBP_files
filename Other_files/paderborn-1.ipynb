# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/K004.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/measuring_log_K004.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F04_K004_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M01_F10_K004_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N09_M07_F10_K004_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K004/N15_M07_F10_K004_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/KA08.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M01_F10_KA08_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F04_KA08_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/measuring_log_KA08.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N09_M07_F10_KA08_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA08/N15_M07_F10_KA08_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/KA07.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/measuring_log_KA07.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N09_M07_F10_KA07_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F10_KA07_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M01_F10_KA07_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA07/N15_M07_F04_KA07_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/measuring_log_KA04.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/KA04.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M01_F10_KA04_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N09_M07_F10_KA04_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F04_KA04_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KA04/N15_M07_F10_KA04_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/measuring_log_KI05.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/KI05.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F10_KI05_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M07_F04_KI05_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N15_M01_F10_KI05_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI05/N09_M07_F10_KI05_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/KB24.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/measuring_log_KB24.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F10_KB24_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M01_F10_KB24_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N15_M07_F04_KB24_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KB24/N09_M07_F10_KB24_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/KI08.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/measuring_log_KI08.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F04_KI08_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M01_F10_KI08_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N15_M07_F10_KI08_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI08/N09_M07_F10_KI08_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/K002.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/measuring_log_K002.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N09_M07_F10_K002_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F04_K002_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M07_F10_K002_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/K002/N15_M01_F10_K002_1.mat
# ...
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/KI16.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F04_KI16_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M01_F10_KI16_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N09_M07_F10_KI16_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/measuring_log_KI16.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI16/N15_M07_F10_KI16_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/KI01.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/measuring_log_KI01.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F04_KI01_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M01_F10_KI01_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N09_M07_F10_KI01_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI01/N15_M07_F10_KI01_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_8.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/KI17.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/measuring_log_KI17.pdf
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_3.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_14.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_9.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_4.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_20.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_18.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_11.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_6.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_1.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_5.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_7.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_10.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F04_KI17_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_16.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_17.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_13.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_15.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M07_F10_KI17_12.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_2.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N15_M01_F10_KI17_19.mat
# /kaggle/input/datasets/dippatel03/paderborn-db/KI17/N09_M07_F10_KI17_3.mat

# %%
import numpy as np
import pandas as pd
import os
import glob
from tqdm.notebook import tqdm
from scipy.io import loadmat

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score
)
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.utils import to_categorical

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU available: {tf.config.list_physical_devices('GPU')}")
# Out:
# 2026-03-20 07:46:44.937482: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773992805.175005      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773992805.243643      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773992805.794432      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773992805.794464      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773992805.794467      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773992805.794469      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version: 2.19.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
#Configuration

INPUT_PATH   = '/kaggle/input/datasets/dippatel03/paderborn-db'
WINDOW_SIZE  = 1024   # samples per segment (1024 @ 64kHz ≈ 16 ms)
STRIDE       = 512    # 50% overlap → doubles dataset size
FILES_PER_FOLDER = 20 # default 

BATCH_SIZE   = 64
EPOCHS       = 100    # EarlyStopping will cut this short
LEARNING_RATE = 1e-3

USE_RESIDUAL = False

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

print("Configuration set.")
# Out:
# Configuration set.

# %%
# def check_size(base_path, files_per_folder=5):
#     folders = ['K001']
#     sizes = []

#     print(f"Found {len(folders)} class folders: {folders}\n")

#     for folder in folders:
#         folder_path = os.path.join(base_path, folder)
#         files = sorted(glob.glob(os.path.join(folder_path, "*.mat")))

#         for file_path in files[:files_per_folder]:
#             print(f"\n📂 File: {file_path}")

#             mat_data = loadmat(file_path)

#             for key in mat_data.keys():
#                 if key.startswith("__"):
#                     continue

#                 try:
#                     data = mat_data[key][0, 0]['Y'][0, 0]['Data']
#                     data_arr = np.array(data).flatten().astype(np.float32)

#                     print(f"✅ Key: {key} → shape: {data_arr.shape}")
#                     sizes.append(data_arr.shape)

#                 except Exception as e:
#                     print(f"❌ Key: {key} → Error: {e}")

#     return sizes

# size = check_size(INPUT_PATH)
# print(size)

# %%
def extract_paderborn_signal(mat_content):
    """
    Extracts the vibration signal from Paderborn .mat files.
    Structure: mat['FileName'][0,0]['Y'][0,0]['Data']
    Falls back to largest array if structure differs.
    """
    for key in mat_content.keys():
        if key.startswith('__'):
            continue
        try:
            data = mat_content[key][0, 0]['Y'][0, 0]['Data']
            return np.array(data).flatten().astype(np.float32)
        except (IndexError, KeyError, TypeError):
            data_array = np.array(mat_content[key])
            return data_array.flatten().astype(np.float32)
    return None


def load_paderborn_dataset(base_path, files_per_folder=20):
    """
    Loads ALL .mat files from every subfolder.
    Each subfolder = one bearing class label.
    """
    all_signals = []
    all_labels  = []

    folders = sorted([
        d for d in os.listdir(base_path)
        if os.path.isdir(os.path.join(base_path, d))
    ])

    print(f"Found {len(folders)} class folders: {folders}\n")

    for folder in tqdm(folders, desc="Loading classes"):
        folder_path = os.path.join(base_path, folder)
        files = sorted(glob.glob(os.path.join(folder_path, "*.mat")))
        files_per_folder = len(files)
        # print(f"Number of .mat files in {folder} is : {files_per_folder}\n")

        loaded = 0
        for file_path in files[:files_per_folder]:
            try:
                mat_data = loadmat(file_path)
                signal   = extract_paderborn_signal(mat_data)
                if signal is not None and len(signal) > WINDOW_SIZE:
                    all_signals.append(signal)
                    all_labels.append(folder)
                    loaded += 1
            except Exception as e:
                print(f"  [WARN] {os.path.basename(file_path)}: {e}")

        # print(f"  {folder}: loaded {loaded}/{len(files[:files_per_folder])} files")

    return pd.DataFrame({'signal': all_signals, 'label': all_labels})


print("Starting data load...")
df = load_paderborn_dataset(INPUT_PATH, files_per_folder=FILES_PER_FOLDER)

print(f"\nTotal files loaded : {len(df)}")
print(f"Classes found      : {sorted(df['label'].unique())}")
print(f"Samples per class  :\n{df['label'].value_counts().sort_index()}")
# Out:
# Starting data load...
# Found 32 class folders: ['K001', 'K002', 'K003', 'K004', 'K005', 'K006', 'KA01', 'KA03', 'KA04', 'KA05', 'KA06', 'KA07', 'KA08', 'KA09', 'KA15', 'KA16', 'KA22', 'KA30', 'KB23', 'KB24', 'KB27', 'KI01', 'KI03', 'KI04', 'KI05', 'KI07', 'KI08', 'KI14', 'KI16', 'KI17', 'KI18', 'KI21']
# Loading classes:   0%|          | 0/32 [00:00<?, ?it/s]
#   [WARN] N15_M01_F10_KA08_2.mat: Expecting matrix here
#
# Total files loaded : 2559
# Classes found      : ['K001', 'K002', 'K003', 'K004', 'K005', 'K006', 'KA01', 'KA03', 'KA04', 'KA05', 'KA06', 'KA07', 'KA08', 'KA09', 'KA15', 'KA16', 'KA22', 'KA30', 'KB23', 'KB24', 'KB27', 'KI01', 'KI03', 'KI04', 'KI05', 'KI07', 'KI08', 'KI14', 'KI16', 'KI17', 'KI18', 'KI21']
# Samples per class  :
# label
# K001    80
# K002    80
# K003    80
# K004    80
# K005    80
# K006    80
# KA01    80
# KA03    80
# KA04    80
# KA05    80
# KA06    80
# KA07    80
# KA08    79
# KA09    80
# KA15    80
# KA16    80
# KA22    80
# KA30    80
# KB23    80
# KB24    80
# KB27    80
# KI01    80
# KI03    80
# KI04    80
# KI05    80
# KI07    80
# KI08    80
# KI14    80
# KI16    80
# KI17    80
# KI18    80
# KI21    80
# Name: count, dtype: int64

# %%
print(f"Example signal shape: {df['signal'][0].shape}")
# Out:
# Example signal shape: (16008,)

# %%
label_encoder = LabelEncoder()
df['label_encoded'] = label_encoder.fit_transform(df['label'])

NUM_CLASSES = len(label_encoder.classes_)
print(f"Number of classes : {NUM_CLASSES}")
print(f"Class mapping     :")
for i, cls in enumerate(label_encoder.classes_):
    print(f"  {i:2d} → {cls}")
# Out:
# Number of classes : 32
# Class mapping     :
#    0 → K001
#    1 → K002
#    2 → K003
#    3 → K004
#    4 → K005
#    5 → K006
#    6 → KA01
#    7 → KA03
#    8 → KA04
#    9 → KA05
#   10 → KA06
#   11 → KA07
#   12 → KA08
#   13 → KA09
#   14 → KA15
#   15 → KA16
#   16 → KA22
#   17 → KA30
#   18 → KB23
#   19 → KB24
#   20 → KB27
#   21 → KI01
#   22 → KI03
#   23 → KI04
#   24 → KI05
#   25 → KI07
#   26 → KI08
#   27 → KI14
#   28 → KI16
#   29 → KI17
#   30 → KI18
#   31 → KI21

# %%
#seperate before segmentation
# ── Split raw signals (file-level) ─────────────────────────────────
# 70% train  |  15% val  |  15% test

df_train_val, df_test = train_test_split(
    df,
    test_size=0.15,
    stratify=df['label'],
    random_state=RANDOM_SEED
)

df_train, df_val = train_test_split(
    df_train_val,
    test_size=0.176,   # 0.176 × 0.85 ≈ 0.15 of total
    stratify=df_train_val['label'],
    random_state=RANDOM_SEED
)

print(f"Raw signal split (file-level):")
print(f"  Train files : {len(df_train)}")
print(f"  Val files   : {len(df_val)}")
print(f"  Test files  : {len(df_test)}")
print(f"  Total       : {len(df_train) + len(df_val) + len(df_test)}")
# Out:
# Raw signal split (file-level):
#   Train files : 1792
#   Val files   : 383
#   Test files  : 384
#   Total       : 2559

# %%
def segment_signals(df_split, window_size=WINDOW_SIZE, stride=STRIDE):
    """
    Splits each long signal into overlapping windows.
    Each segment is Z-score normalised independently.
    Returns:
        X : np.ndarray of shape (N, window_size)
        y : np.ndarray of shape (N,) with integer labels
    """
    X_list = []
    y_list = []

    for _, row in df_split.iterrows():
        signal = row['signal']
        label  = row['label_encoded']

        for start in range(0, len(signal) - window_size, stride):
            end     = start + window_size
            segment = signal[start:end]

            # Per-segment Z-score normalisation
            mu  = segment.mean()
            std = segment.std() + 1e-8
            segment = (segment - mu) / std

            X_list.append(segment)
            y_list.append(label)

    return np.array(X_list, dtype=np.float32), np.array(y_list, dtype=np.int32)


# Segment each split independently — NO data leakage!
print(f"Segmenting with window={WINDOW_SIZE}, stride={STRIDE}...")

X_train, y_train = segment_signals(df_train)
print(f"  Train segments : {X_train.shape[0]}")

X_val, y_val = segment_signals(df_val)
print(f"  Val segments   : {X_val.shape[0]}")

X_test, y_test = segment_signals(df_test)
print(f"  Test segments  : {X_test.shape[0]}")

print(f"\nTotal segments   : {X_train.shape[0] + X_val.shape[0] + X_test.shape[0]}")

# Print class distribution per split
for name, y_arr in [('Train', y_train), ('Val', y_val), ('Test', y_test)]:
    unique, counts = np.unique(y_arr, return_counts=True)
    print(f"\n{name} segments per class:")
    for u, c in zip(unique, counts):
        print(f"  {label_encoder.classes_[u]}: {c}")
# Out:
# Segmenting with window=1024, stride=512...
#   Train segments : 53762
#   Val segments   : 11490
#   Test segments  : 11525
#
# Total segments   : 76777
#
# Train segments per class:
#   K001: 1680
#   K002: 1680
#   K003: 1680
#   K004: 1680
#   K005: 1680
#   K006: 1680
#   KA01: 1680
#   KA03: 1680
#   KA04: 1680
#   KA05: 1680
#   KA06: 1680
#   KA07: 1680
#   KA08: 1680
#   KA09: 1680
#   KA15: 1680
#   KA16: 1680
#   KA22: 1680
#   KA30: 1680
#   KB23: 1680
#   KB24: 1680
#   KB27: 1680
#   KI01: 1680
#   KI03: 1680
#   KI04: 1680
#   KI05: 1680
#   KI07: 1680
#   KI08: 1680
#   KI14: 1680
#   KI16: 1682
#   KI17: 1680
#   KI18: 1680
#   KI21: 1680
#
# Val segments per class:
#   K001: 360
#   K002: 360
#   K003: 360
#   K004: 360
#   K005: 360
#   K006: 360
#   KA01: 360
#   KA03: 360
#   KA04: 360
#   KA05: 360
#   KA06: 360
#   KA07: 360
#   KA08: 330
#   KA09: 360
#   KA15: 360
#   KA16: 360
#   KA22: 360
#   KA30: 360
#   KB23: 360
#   KB24: 360
#   KB27: 360
#   KI01: 360
#   KI03: 360
#   KI04: 360
#   KI05: 360
#   KI07: 360
#   KI08: 360
#   KI14: 360
#   KI16: 360
#   KI17: 360
#   KI18: 360
#   KI21: 360
#
# Test segments per class:
#   K001: 360
#   K002: 360
#   K003: 360
#   K004: 360
#   K005: 360
#   K006: 360
#   KA01: 360
#   KA03: 360
#   KA04: 360
#   KA05: 360
#   KA06: 360
#   KA07: 360
#   KA08: 360
#   KA09: 360
#   KA15: 360
#   KA16: 360
#   KA22: 360
#   KA30: 360
#   KB23: 360
#   KB24: 360
#   KB27: 360
#   KI01: 360
#   KI03: 360
#   KI04: 360
#   KI05: 360
#   KI07: 360
#   KI08: 360
#   KI14: 360
#   KI16: 365
#   KI17: 360
#   KI18: 360
#   KI21: 360

# %%
# Reshape for Keras: (N, time_steps, channels)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val   = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test  = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

print(f"Train : {X_train.shape}")
print(f"Val   : {X_val.shape}")
print(f"Test  : {X_test.shape}")

# One-hot encode labels for Keras
y_train_oh = to_categorical(y_train, NUM_CLASSES)
y_val_oh   = to_categorical(y_val,   NUM_CLASSES)
y_test_oh  = to_categorical(y_test,  NUM_CLASSES)
# Out:
# Train : (53762, 1024, 1)
# Val   : (11490, 1024, 1)
# Test  : (11525, 1024, 1)

# %%
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=y_train
)
class_weights_dict = {i: w for i, w in enumerate(class_weights_array)}
print("Class weights computed:")
for i, w in class_weights_dict.items():
    print(f"  Class {i:2d} ({label_encoder.classes_[i]}): {w:.3f}")
# Out:
# Class weights computed:
#   Class  0 (K001): 1.000
#   Class  1 (K002): 1.000
#   Class  2 (K003): 1.000
#   Class  3 (K004): 1.000
#   Class  4 (K005): 1.000
#   Class  5 (K006): 1.000
#   Class  6 (KA01): 1.000
#   Class  7 (KA03): 1.000
#   Class  8 (KA04): 1.000
#   Class  9 (KA05): 1.000
#   Class 10 (KA06): 1.000
#   Class 11 (KA07): 1.000
#   Class 12 (KA08): 1.000
#   Class 13 (KA09): 1.000
#   Class 14 (KA15): 1.000
#   Class 15 (KA16): 1.000
#   Class 16 (KA22): 1.000
#   Class 17 (KA30): 1.000
#   Class 18 (KB23): 1.000
#   Class 19 (KB24): 1.000
#   Class 20 (KB27): 1.000
#   Class 21 (KI01): 1.000
#   Class 22 (KI03): 1.000
#   Class 23 (KI04): 1.000
#   Class 24 (KI05): 1.000
#   Class 25 (KI07): 1.000
#   Class 26 (KI08): 1.000
#   Class 27 (KI14): 1.000
#   Class 28 (KI16): 0.999
#   Class 29 (KI17): 1.000
#   Class 30 (KI18): 1.000
#   Class 31 (KI21): 1.000

# %%
# ──────────────────────────────────────────────────────────────────
# BUILDING BLOCKS
# ──────────────────────────────────────────────────────────────────

def conv_bn_relu(x, filters, kernel_size, strides=1):
    """Conv → BatchNorm → ReLU"""
    x = layers.Conv1D(
        filters, kernel_size,
        strides=strides,
        padding='same',
        use_bias=False,
        kernel_initializer='he_normal'
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x


# ──────────────────────────────────────────────────────────────────
# MODEL FACTORY — Standard CNN Only
# ──────────────────────────────────────────────────────────────────

def build_cnn(input_shape, num_classes):
    """
    Deep 1D CNN for vibration-based bearing fault classification.

    Args:
        input_shape  : (window_size, channels) — e.g. (1024, 1)
        num_classes  : number of fault/health categories
    """
    inputs = Input(shape=input_shape, name='vibration_input')
    x = inputs

    # Block 1: wide kernel to capture low-freq patterns
    x = conv_bn_relu(x, 64,  kernel_size=7)
    x = layers.MaxPooling1D(pool_size=4)(x)          # 1024 → 256

    # Block 2
    x = conv_bn_relu(x, 128, kernel_size=5)
    x = layers.MaxPooling1D(pool_size=4)(x)          # 256 → 64

    # Block 3
    x = conv_bn_relu(x, 256, kernel_size=3)
    x = layers.MaxPooling1D(pool_size=4)(x)          # 64 → 16

    # Block 4: no downsampling — refine features
    x = conv_bn_relu(x, 256, kernel_size=3)

    # ── HEAD ────────────────────────────────────────────────────────
    x = layers.GlobalAveragePooling1D()(x)               # fixed-size vector, no params

    x = layers.Dense(256, use_bias=False, kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(128, use_bias=False, kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(num_classes, activation='softmax', name='predictions')(x)

    model = Model(inputs=inputs, outputs=outputs, name='DeepCNN1D')
    return model


# Build the model
model = build_cnn(
    input_shape=(WINDOW_SIZE, 1),
    num_classes=NUM_CLASSES
)

model.summary()
# Out:
# I0000 00:00:1773993286.412317      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1773993286.418242      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "DeepCNN1D"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vibration_input (InputLayer)    │ (None, 1024, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 1024, 64)       │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1024, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 256, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 256, 128)       │        40,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 64, 256)        │        98,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 64, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 16, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 16, 256)        │       196,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 32)             │         4,128 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 443,104 (1.69 MB)
#  Trainable params: 440,928 (1.68 MB)
#  Non-trainable params: 2,176 (8.50 KB)

# %%
# ── Compile ──────────────────────────────────────────────────────
optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ── Callbacks ────────────────────────────────────────────────────
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=7,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    ),
]

# ── Train ─────────────────────────────────────────────────────────
history = model.fit(
    X_train, y_train_oh,
    batch_size=BATCH_SIZE,
    epochs=20,
    validation_data=(X_val, y_val_oh),
    class_weight=class_weights_dict,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/20
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5341 - loss: 1.5683
# Epoch 1: val_accuracy improved from -inf to 0.71036, saving model to best_model.keras
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.5343 - loss: 1.5675 - val_accuracy: 0.7104 - val_loss: 0.7609 - learning_rate: 0.0010
# Epoch 2/20
# 839/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9081 - loss: 0.2764
# Epoch 2: val_accuracy improved from 0.71036 to 0.82045, saving model to best_model.keras
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9082 - loss: 0.2762 - val_accuracy: 0.8205 - val_loss: 0.6118 - learning_rate: 0.0010
# Epoch 3/20
# 838/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9516 - loss: 0.1444
# Epoch 3: val_accuracy improved from 0.82045 to 0.97946, saving model to best_model.keras
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9517 - loss: 0.1444 - val_accuracy: 0.9795 - val_loss: 0.0619 - learning_rate: 0.0010
# Epoch 4/20
# 836/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9580 - loss: 0.1246
# Epoch 4: val_accuracy did not improve from 0.97946
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9580 - loss: 0.1244 - val_accuracy: 0.8807 - val_loss: 0.3926 - learning_rate: 0.0010
# Epoch 5/20
# 838/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9515 - loss: 0.1419
# Epoch 5: val_accuracy did not improve from 0.97946
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9516 - loss: 0.1417 - val_accuracy: 0.9187 - val_loss: 0.2684 - learning_rate: 0.0010
# Epoch 6/20
# 840/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9801 - loss: 0.0588
# Epoch 6: val_accuracy did not improve from 0.97946
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9801 - loss: 0.0588 - val_accuracy: 0.7128 - val_loss: 1.2838 - learning_rate: 0.0010
# Epoch 7/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9179 - loss: 0.2656
# Epoch 7: val_accuracy did not improve from 0.97946
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9183 - loss: 0.2644 - val_accuracy: 0.9702 - val_loss: 0.0874 - learning_rate: 0.0010
# Epoch 8/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9610 - loss: 0.1162
# Epoch 8: val_accuracy did not improve from 0.97946
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9611 - loss: 0.1159 - val_accuracy: 0.9718 - val_loss: 0.0801 - learning_rate: 0.0010
# Epoch 9/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9822 - loss: 0.0541
# Epoch 9: val_accuracy did not improve from 0.97946
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9822 - loss: 0.0540 - val_accuracy: 0.9753 - val_loss: 0.0666 - learning_rate: 0.0010
# Epoch 10/20
# 835/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.0465
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_accuracy did not improve from 0.97946
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9840 - loss: 0.0465 - val_accuracy: 0.9359 - val_loss: 0.2257 - learning_rate: 0.0010
# Epoch 11/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9863 - loss: 0.0412
# Epoch 11: val_accuracy improved from 0.97946 to 0.99043, saving model to best_model.keras
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9864 - loss: 0.0411 - val_accuracy: 0.9904 - val_loss: 0.0258 - learning_rate: 5.0000e-04
# Epoch 12/20
# 840/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9894 - loss: 0.0309
# Epoch 12: val_accuracy improved from 0.99043 to 0.99060, saving model to best_model.keras
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9894 - loss: 0.0309 - val_accuracy: 0.9906 - val_loss: 0.0242 - learning_rate: 5.0000e-04
# Epoch 13/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9904 - loss: 0.0272
# Epoch 13: val_accuracy did not improve from 0.99060
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9904 - loss: 0.0272 - val_accuracy: 0.9903 - val_loss: 0.0263 - learning_rate: 5.0000e-04
# Epoch 14/20
# 840/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9935 - loss: 0.0209
# Epoch 14: val_accuracy did not improve from 0.99060
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9935 - loss: 0.0209 - val_accuracy: 0.9882 - val_loss: 0.0356 - learning_rate: 5.0000e-04
# Epoch 15/20
# 840/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9930 - loss: 0.0228
# Epoch 15: val_accuracy did not improve from 0.99060
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9930 - loss: 0.0228 - val_accuracy: 0.9853 - val_loss: 0.0467 - learning_rate: 5.0000e-04
# Epoch 16/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.0176
# Epoch 16: val_accuracy did not improve from 0.99060
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9945 - loss: 0.0176 - val_accuracy: 0.9727 - val_loss: 0.0901 - learning_rate: 5.0000e-04
# Epoch 17/20
# 840/841 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - loss: 0.0172
# Epoch 17: val_accuracy did not improve from 0.99060
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9946 - loss: 0.0172 - val_accuracy: 0.9880 - val_loss: 0.0392 - learning_rate: 5.0000e-04
# Epoch 18/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.0239
# Epoch 18: val_accuracy improved from 0.99060 to 0.99252, saving model to best_model.keras
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9917 - loss: 0.0239 - val_accuracy: 0.9925 - val_loss: 0.0220 - learning_rate: 5.0000e-04
# Epoch 19/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0179
# Epoch 19: val_accuracy did not improve from 0.99252
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9944 - loss: 0.0179 - val_accuracy: 0.9758 - val_loss: 0.0851 - learning_rate: 5.0000e-04
# Epoch 20/20
# 834/841 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9948 - loss: 0.0152
# Epoch 20: val_accuracy improved from 0.99252 to 0.99504, saving model to best_model.keras
# 841/841 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9948 - loss: 0.0152 - val_accuracy: 0.9950 - val_loss: 0.0140 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 20.

# %%
# ── Training curves ──────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss
axes[0].plot(history.history['loss'], label='Train Loss')
axes[0].plot(history.history['val_loss'], label='Val Loss')
axes[0].set_title('Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Accuracy
axes[1].plot(history.history['accuracy'], label='Train Accuracy')
axes[1].plot(history.history['val_accuracy'], label='Val Accuracy')
axes[1].set_title('Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# ── Test set evaluation ──────────────────────────────────────────
test_loss, test_acc = model.evaluate(X_test, y_test_oh, verbose=0)
print(f"Test Loss     : {test_loss:.4f}")
print(f"Test Accuracy : {test_acc:.4f}")

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

print(f"\nWeighted F1 : {f1_score(y_test, y_pred, average='weighted'):.4f}")
print(f"Macro F1    : {f1_score(y_test, y_pred, average='macro'):.4f}")
# Out:
# Test Loss     : 0.0223
# Test Accuracy : 0.9927
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# Weighted F1 : 0.9927
# Macro F1    : 0.9927

# %%
# ── Classification Report ────────────────────────────────────────
print("\nClassification Report:")
print(classification_report(
    y_test, y_pred,
    target_names=label_encoder.classes_
))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         K001       1.00      1.00      1.00       360
#         K002       1.00      1.00      1.00       360
#         K003       0.90      0.98      0.94       360
#         K004       1.00      1.00      1.00       360
#         K005       1.00      1.00      1.00       360
#         K006       0.98      0.89      0.93       360
#         KA01       1.00      1.00      1.00       360
#         KA03       1.00      0.97      0.98       360
#         KA04       1.00      1.00      1.00       360
#         KA05       1.00      1.00      1.00       360
#         KA06       0.99      1.00      1.00       360
#         KA07       1.00      1.00      1.00       360
#         KA08       1.00      1.00      1.00       360
#         KA09       1.00      1.00      1.00       360
#         KA15       0.96      1.00      0.98       360
#         KA16       1.00      1.00      1.00       360
#         KA22       1.00      0.96      0.98       360
#         KA30       1.00      1.00      1.00       360
#         KB23       1.00      1.00      1.00       360
#         KB24       1.00      1.00      1.00       360
#         KB27       1.00      1.00      1.00       360
#         KI01       1.00      1.00      1.00       360
#         KI03       1.00      1.00      1.00       360
#         KI04       1.00      1.00      1.00       360
#         KI05       1.00      1.00      1.00       360
#         KI07       0.97      0.99      0.98       360
#         KI08       1.00      1.00      1.00       360
#         KI14       1.00      1.00      1.00       360
#         KI16       1.00      1.00      1.00       365
#         KI17       1.00      1.00      1.00       360
#         KI18       1.00      1.00      1.00       360
#         KI21       0.99      1.00      1.00       360
#
#     accuracy                           0.99     11525
#    macro avg       0.99      0.99      0.99     11525
# weighted avg       0.99      0.99      0.99     11525

# %%
# ── Confusion Matrix ─────────────────────────────────────────────
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(14, 12))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=label_encoder.classes_,
    yticklabels=label_encoder.classes_
)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
